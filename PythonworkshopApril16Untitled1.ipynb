# %% [markdown]
# <a href="https://colab.research.google.com/github/lc3359/planets/blob/master/PythonworkshopApril16Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# %%
import altair as alt

# %%
# !pip install vega_datasets # to upload through Jupiter

# %%
cars.head()
# Out:
#    Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
# 0          12.0          8         307.0       130.0              18.0
# 1          11.5          8         350.0       165.0              15.0
# 2          11.0          8         318.0       150.0              18.0
# 3          12.0          8         304.0       150.0              16.0
# 4          10.5          8         302.0       140.0              17.0
#
#                         Name Origin  Weight_in_lbs       Year
# 0  chevrolet chevelle malibu    USA           3504 1970-01-01
# 1          buick skylark 320    USA           3693 1970-01-01
# 2         plymouth satellite    USA           3436 1970-01-01
# 3              amc rebel sst    USA           3433 1970-01-01
# 4                ford torino    USA           3449 1970-01-01

# %%
cars.groupby(by = 'Origin').mean()
# Out:
#         Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
# Origin
# Europe     16.821918   4.150685    109.465753   81.000000         27.891429
# Japan      16.172152   4.101266    102.708861   79.835443         30.450633
# USA        14.942520   6.283465    247.935039  119.900000         20.083534
#
#         Weight_in_lbs
# Origin
# Europe    2431.493151
# Japan     2221.227848
# USA       3372.700787

# %%
cars.groupby(by = 'Origin').mean()['Weight_in_lbs'].plot(kind='bar')

# %%
alt.Chart(cars).mark_bar().encode(
  x = 'mean(Miles_per_Gallon)',
  y = 'Origin',
  color = 'Origin').interactive()
# Out:
# Chart({
#   data:      Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
#   0            12.0          8         307.0       130.0              18.0
#   1            11.5          8         350.0       165.0              15.0
#   2            11.0          8         318.0       150.0              18.0
#   3            12.0          8         304.0       150.0              16.0
#   4            10.5          8         302.0       140.0              17.0
#   5            10.0          8         429.0       198.0              15.0
#   6             9.0          8         454.0       220.0              14.0
#   7             8.5          8         440.0       215.0              14.0
#   8            10.0          8         455.0       225.0              14.0
#   9             8.5          8         390.0       190.0              15.0
#   10           17.5          4         133.0       115.0               NaN
# ...
